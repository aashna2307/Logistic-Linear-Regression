# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_train = pd.read_csv('train.csv', index_col='Name')
titanic_train
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [891 rows x 11 columns]

# %%
sns.heatmap(titanic_train.corr())

# %%
train_df = pd.DataFrame(titanic_train)
train_df.head(15)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Palsson, Master. Gosta Leonard                                8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# Sandstrom, Miss. Marguerite Rut                              11         1
# Bonnell, Miss. Elizabeth                                     12         1
# Saundercock, Mr. William Henry                               13         0
# Andersson, Mr. Anders Johan                                  14         0
# Vestrom, Miss. Hulda Amanda Adolfina                         15         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# McCarthy, Mr. Timothy J                                  1    male  54.0
# Palsson, Master. Gosta Leonard                           3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                      2  female  14.0
# Sandstrom, Miss. Marguerite Rut                          3  female   4.0
# Bonnell, Miss. Elizabeth                                 1  female  58.0
# Saundercock, Mr. William Henry                           3    male  20.0
# Andersson, Mr. Anders Johan                              3    male  39.0
# Vestrom, Miss. Hulda Amanda Adolfina                     3  female  14.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
# Moran, Mr. James                                        0      0
# McCarthy, Mr. Timothy J                                 0      0
# Palsson, Master. Gosta Leonard                          3      1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       0      2
# Nasser, Mrs. Nicholas (Adele Achem)                     1      0
# Sandstrom, Miss. Marguerite Rut                         1      1
# Bonnell, Miss. Elizabeth                                0      0
# Saundercock, Mr. William Henry                          0      0
# Andersson, Mr. Anders Johan                             1      5
# Vestrom, Miss. Hulda Amanda Adolfina                    0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# McCarthy, Mr. Timothy J                                        17463  51.8625
# Palsson, Master. Gosta Leonard                                349909  21.0750
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             347742  11.1333
# Nasser, Mrs. Nicholas (Adele Achem)                           237736  30.0708
# Sandstrom, Miss. Marguerite Rut                              PP 9549  16.7000
# Bonnell, Miss. Elizabeth                                      113783  26.5500
# Saundercock, Mr. William Henry                             A/5. 2151   8.0500
# Andersson, Mr. Anders Johan                                   347082  31.2750
# Vestrom, Miss. Hulda Amanda Adolfina                          350406   7.8542
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# McCarthy, Mr. Timothy J                              E46        S
# Palsson, Master. Gosta Leonard                       NaN        S
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    NaN        S
# Nasser, Mrs. Nicholas (Adele Achem)                  NaN        C
# Sandstrom, Miss. Marguerite Rut                       G6        S
# Bonnell, Miss. Elizabeth                            C103        S
# Saundercock, Mr. William Henry                       NaN        S
# Andersson, Mr. Anders Johan                          NaN        S
# Vestrom, Miss. Hulda Amanda Adolfina                 NaN        S

# %%
train_df.drop(['Ticket', 'Fare', 'Cabin', 'Embarked', 'Pclass', 'Sex'], axis = 1, inplace = True)
train_df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                      Age  SibSp  Parch
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
# [891 rows x 5 columns]

# %%
age = train_df['Age']
#age
age_mean = age.mean()
age_mean = int(age_mean)
age.fillna(age_mean, inplace= True)
age.describe()
# Out:
# count    891.000000
# mean      29.560236
# std       13.005010
# min        0.420000
# 25%       22.000000
# 50%       29.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
X_train = train_df.iloc[:, [3, 4]].values
y_train = train_df.iloc[:, 2].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(X_train,y_train,test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train, y_train) #gives the best fit line
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(x_test) #x-test is the values for testing
y_pred
# Out:
# array([31.2765257 , 31.2765257 , 21.38744612, 29.16060295, 28.42574848,
#        31.2765257 , 31.2765257 , 28.42574848, 29.16060295, 31.2765257 ,
#        29.16060295, 31.2765257 , 31.2765257 , 28.42574848, 31.2765257 ,
#        31.2765257 , 31.2765257 , 27.73521435, 31.2765257 , 29.85113709,
#        31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 ,
#        27.73521435, 31.2765257 , 31.2765257 , 29.85113709, 22.07798025,
#        31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 , 29.16060295,
#        31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 ,
#        27.73521435, 31.2765257 , 31.2765257 , 21.38744612, 29.16060295,
#        31.2765257 , 31.2765257 , 24.193903  , 31.2765257 , 27.73521435,
#        31.2765257 , 29.85113709, 27.73521435, 31.2765257 , 31.2765257 ,
#        27.04468021, 31.2765257 , 19.96205751, 22.07798025, 27.04468021,
#        31.2765257 , 25.57497127, 29.16060295, 31.2765257 , 28.42574848,
#        31.2765257 , 31.2765257 , 29.85113709, 27.73521435, 31.2765257 ,
#        29.16060295, 29.16060295, 29.16060295, 31.2765257 , 31.2765257 ,
#        24.92875747, 22.07798025, 31.2765257 , 31.2765257 , 31.2765257 ,
#        29.16060295, 27.73521435, 27.73521435, 31.2765257 , 31.2765257 ,
#        31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 , 29.16060295,
#        31.2765257 , 31.2765257 , 27.73521435, 29.85113709, 22.07798025,
#        31.2765257 , 28.42574848, 21.38744612, 31.2765257 , 31.2765257 ,
#        17.84613476, 29.16060295, 31.2765257 , 27.73521435, 27.73521435,
#        27.73521435, 31.2765257 , 24.14958266, 29.16060295, 29.16060295,
#        31.2765257 , 29.85113709, 31.2765257 , 31.2765257 , 26.30982574,
#        31.2765257 , 29.16060295, 29.16060295, 31.2765257 , 27.73521435,
#        31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 ,
#        31.2765257 , 31.2765257 , 29.16060295, 31.2765257 , 31.2765257 ,
#        31.2765257 , 31.2765257 , 31.2765257 , 29.16060295, 31.2765257 ,
#        31.2765257 , 29.16060295, 29.16060295, 29.16060295, 31.2765257 ,
#        31.2765257 , 29.16060295, 31.2765257 , 31.2765257 , 31.2765257 ,
#        31.2765257 , 31.2765257 , 29.16060295, 29.85113709, 31.2765257 ,
#        29.16060295, 31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 ,
#        31.2765257 , 29.85113709, 31.2765257 , 31.2765257 , 25.6192916 ,
#        31.2765257 , 31.2765257 , 29.16060295, 24.92875747, 27.73521435,
#        31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 , 31.2765257 ,
#        31.2765257 , 29.16060295, 31.2765257 , 31.2765257 , 31.2765257 ,
#        31.2765257 , 29.16060295, 31.2765257 , 31.2765257 ])

# %%
accuracy = np.abs(np.mean(y_pred - y_test))
accuracy
# Out:
# 0.32716352184736486

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.08550971473353286

# %%
def mse(y_true, y_predicted):
    return np.mean((y_true-y_predicted) ** 2)

mse_value=mse(y_test, y_pred)
print(mse_value)
# Out:
# 146.31746965165763

# %%
#y_pred_line=regressor.predict(X)
cmap=plt.get_cmap('viridis')
fig=plt.figure(figsize=(4,4))
m1=plt.scatter(X_train, y_train, color=cmap(0.9), s=20)
m2=plt.scatter(X_test, y_test, color=cmap(0.5), s=10)
plt.plot(X, y_pred_line, color='black', linewidth=2, label="Prediction")

plt.show()
